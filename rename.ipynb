# %%
import os
import pandas as pd
import chardet

# %%
with open('alertes/Alertes_-2023.csv', 'rb') as file :
    encodage = chardet.detect(file.read(10000))

print(encodage)
# Out:
# {'encoding': 'UTF-8-SIG', 'confidence': 1.0, 'language': ''}

# %%
pd.options.display.max_columns = None
df = pd.read_csv('alertes/Alertes_-2023.csv', sep=';', encoding='utf-8-sig', parse_dates=['Date'])
# Out:
# C:\Users\bcoulet\AppData\Local\Temp\ipykernel_4056\3704667413.py:2: UserWarning: Parsing dates in %d/%m/%Y %H:%M format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df = pd.read_csv('alertes/Alertes_-2023.csv', sep=';', encoding='utf-8-sig', parse_dates=['Date'])

# %%
df.head(2)
# Out:
#   Référence                Date   Timestamp   Communauté  Émetteur  \
# 0  1,51E+15 2023-12-31 18:17:00  1704043020  RTM Usagers       NaN
# 1  1,42E+15 2023-12-31 18:13:00  1704042780  RTM Usagers       NaN
#
#    Durée en secondes           Mode de déclenchement  Qualification émetteur  \
# 0                  4  Bouton SOS Principal (Message)                     NaN
# 1                 23  Bouton SOS Principal (Message)                     NaN
#
#   Qualification récepteur  Nombre de qualifications  Nombre de récepteurs  \
# 0           Fausse alerte                         1                     2
# 1           Fausse alerte                         1                     2
#
#    Délai de réception en secondes  Nombre d'intervenants  \
# 0                             0.0                      1
# 1                             0.0                      1
#
#    Délai de prise en charge en secondes  Qualité de la transmission  \
# ...

# %%
for col in df.columns:
    print(f"{col} => {df[col].dtype}")
# Out:
# Référence => object
# Date => datetime64[ns]
# Timestamp => int64
# Communauté => object
# Émetteur => float64
# Durée en secondes => int64
# Mode de déclenchement => object
# Qualification émetteur => float64
# Qualification récepteur => object
# Nombre de qualifications => int64
# Nombre de récepteurs => int64
# Délai de réception en secondes => float64
# Nombre d'intervenants => int64
# Délai de prise en charge en secondes => float64
# Qualité de la transmission => int64
# Nombre de messages => int64
# Nombre de sessions talkie walkie => int64
# Position initiale : latitude => float64
# Position initiale : longitude => float64
# Position initiale : précision en mètres => int64
# Position initiale : rue => float64
# Position initiale : code postal => float64
# Position initiale : ville => object
# Position initiale : département => object
# Position initiale : région => object
# Position initiale : pays => object
# Position initiale : lien Google Maps => object
# ...

# %%
df["Date"].dtype
# Out:
# dtype('<M8[ns]')

# %% [markdown]
# Converti la colonne Date en datetime

# %%
df["Date"] = pd.to_datetime(df["Date"], dayfirst=True, errors="coerce")
print(df["Date"])
# Out:
# 0       2023-12-31 18:17:00
# 1       2023-12-31 18:13:00
# 2       2023-12-31 18:13:00
# 3       2023-12-31 18:13:00
# 4       2023-12-31 18:12:00
#                 ...
# 16427   2023-01-16 10:06:00
# 16428   2023-01-16 10:00:00
# 16429   2023-01-16 09:54:00
# 16430   2023-01-16 09:53:00
# 16431   2023-01-16 09:51:00
# Name: Date, Length: 16432, dtype: datetime64[ns]

# %%
# for col in df.columns:
#     print(f"{col} => {df[col].dtype}")
df["Date"].dtype
# Out:
# dtype('<M8[ns]')

# %% [markdown]
# 2025 semble problématique

# %%
with open('alertes/Alertes_-2025-01.csv', 'rb') as file :
    encodage = chardet.detect(file.read(10000))

print(encodage)
# Out:
# {'encoding': 'UTF-8-SIG', 'confidence': 1.0, 'language': ''}

# %%
pd.options.display.max_columns = None
df_2025 = pd.read_csv('alertes/Alertes_-2025-01.csv', sep=';', encoding='utf-8-sig')

# %%
df_2025.head(2)
# Out:
#     Référence              Date   Timestamp   Communauté  Émetteur  \
# 0  1738353630  2025/01/31 21:00  1738353600  RTM Usagers       NaN
# 1  1738353599  2025/01/31 20:59  1738353540  RTM Usagers       NaN
#
#    Durée en secondes           Mode de déclenchement  Qualification émetteur  \
# 0                111  Bouton SOS Principal (Message)                     NaN
# 1                 25    Bouton SOS Principal (Appel)                     NaN
#
#   Qualification récepteur  Nombre de qualifications  Nombre de récepteurs  \
# 0           Fausse alerte                         1                     2
# 1           Fausse alerte                         1                     2
#
#    Délai de réception en secondes  Nombre d'intervenants  \
# 0                               0                      1
# 1                               0                      1
#
#    Délai de prise en charge en secondes  Qualité de la transmission  \
# ...

# %%
df_2025["Date"].dtype
# Out:
# dtype('O')

# %%
for col in df.columns:
    print(f"{col} => {df[col].dtype}")
# Out:
# Référence => object
# Date => datetime64[ns]
# Timestamp => int64
# Communauté => object
# Émetteur => float64
# Durée en secondes => int64
# Mode de déclenchement => object
# Qualification émetteur => float64
# Qualification récepteur => object
# Nombre de qualifications => int64
# Nombre de récepteurs => int64
# Délai de réception en secondes => float64
# Nombre d'intervenants => int64
# Délai de prise en charge en secondes => float64
# Qualité de la transmission => int64
# Nombre de messages => int64
# Nombre de sessions talkie walkie => int64
# Position initiale : latitude => float64
# Position initiale : longitude => float64
# Position initiale : précision en mètres => int64
# Position initiale : rue => float64
# Position initiale : code postal => float64
# Position initiale : ville => object
# Position initiale : département => object
# Position initiale : région => object
# Position initiale : pays => object
# Position initiale : lien Google Maps => object
# ...
